# %%
import numpy as np 
import pandas as pd

# %%
s = pd.Series([1,2,3,np.nan,5])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
dates = pd.date_range('20200101', periods=5)

# %%
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(5,4),index=dates,columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2020-01-01 -0.370018 -1.950644  0.454098  0.585482
# 2020-01-02 -1.137113 -0.538359 -0.151470  0.393029
# 2020-01-03  0.530750  0.773024 -0.885727  0.633540
# 2020-01-04 -0.553233  0.227245  0.298894 -1.769816
# 2020-01-05  0.682736  0.216744 -2.093730 -1.011849

# %%
df2 = pd.DataFrame({'A': 1.,
   ...:                     'B': pd.Timestamp('20130102'),
   ...:                     'C': pd.Series(1, index=list(range(4)), dtype='float32'),
   ...:                     'D': np.array([3] * 4, dtype='int32'),
   ...:                     'E': pd.Categorical(["test", "train", "test", "train"]),
   ...:                     'F': 'foo'})

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2020-01-01 -0.370018 -1.950644  0.454098  0.585482
# 2020-01-02 -1.137113 -0.538359 -0.151470  0.393029
# 2020-01-03  0.530750  0.773024 -0.885727  0.633540
# 2020-01-04 -0.553233  0.227245  0.298894 -1.769816
# 2020-01-05  0.682736  0.216744 -2.093730 -1.011849

# %%
df2.tail()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.37001754, -1.95064442,  0.45409776,  0.58548181],
#        [-1.13711342, -0.53835918, -0.1514704 ,  0.39302889],
#        [ 0.53075017,  0.77302391, -0.88572745,  0.63354038],
#        [-0.55323334,  0.22724471,  0.2988941 , -1.76981577],
#        [ 0.68273614,  0.21674421, -2.09372954, -1.01184861]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  5.000000  5.000000  5.000000  5.000000
# mean  -0.169376 -0.254398 -0.475587 -0.233923
# std    0.764917  1.056816  1.043526  1.093289
# min   -1.137113 -1.950644 -2.093730 -1.769816
# 25%   -0.553233 -0.538359 -0.885727 -1.011849
# 50%   -0.370018  0.216744 -0.151470  0.393029
# 75%    0.530750  0.227245  0.298894  0.585482
# max    0.682736  0.773024  0.454098  0.633540

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2020-01-01  0.585482  0.454098 -1.950644 -0.370018
# 2020-01-02  0.393029 -0.151470 -0.538359 -1.137113
# 2020-01-03  0.633540 -0.885727  0.773024  0.530750
# 2020-01-04 -1.769816  0.298894  0.227245 -0.553233
# 2020-01-05 -1.011849 -2.093730  0.216744  0.682736

# %%
df.sort_values(by='B',ascending=True)
# Out:
#                    A         B         C         D
# 2020-01-01 -0.370018 -1.950644  0.454098  0.585482
# 2020-01-02 -1.137113 -0.538359 -0.151470  0.393029
# 2020-01-05  0.682736  0.216744 -2.093730 -1.011849
# 2020-01-04 -0.553233  0.227245  0.298894 -1.769816
# 2020-01-03  0.530750  0.773024 -0.885727  0.633540

# %%
df[1:3]
# Out:
#                    A         B         C         D
# 2020-01-02 -1.137113 -0.538359 -0.151470  0.393029
# 2020-01-03  0.530750  0.773024 -0.885727  0.633540

# %%
df.loc['2020-01-02':'2020-01-04',['A']]
# Out:
#                    A
# 2020-01-02 -1.137113
# 2020-01-03  0.530750
# 2020-01-04 -0.553233

# %%
df.iloc[:,2:4]
# Out:
#                    C         D
# 2020-01-01  0.454098  0.585482
# 2020-01-02 -0.151470  0.393029
# 2020-01-03 -0.885727  0.633540
# 2020-01-04  0.298894 -1.769816
# 2020-01-05 -2.093730 -1.011849

# %%
df[df.B < 0]
# Out:
#                    A         B         C         D
# 2020-01-01 -0.370018 -1.950644  0.454098  0.585482
# 2020-01-02 -1.137113 -0.538359 -0.151470  0.393029

# %%
s = pd.Series([2,4,6,8,10],index=pd.date_range('20200101',periods=5))

# %%
s
# Out:
# 2020-01-01     2
# 2020-01-02     4
# 2020-01-03     6
# 2020-01-04     8
# 2020-01-05    10
# Freq: D, dtype: int64

# %%
df['E']=s

# %%
df
# Out:
#                    A         B         C         D   E
# 2020-01-01 -0.370018 -1.950644  0.454098  0.585482   2
# 2020-01-02 -1.137113 -0.538359 -0.151470  0.393029   4
# 2020-01-03  0.530750  0.773024 -0.885727  0.633540   6
# 2020-01-04 -0.553233  0.227245  0.298894 -1.769816   8
# 2020-01-05  0.682736  0.216744 -2.093730 -1.011849  10

# %%
df.at['2020-01-01','A']=0

# %%
df
# Out:
#                    A         B         C         D   E
# 2020-01-01  0.000000 -1.950644  0.454098  0.585482   2
# 2020-01-02 -1.137113 -0.538359 -0.151470  0.393029   4
# 2020-01-03  0.530750  0.773024 -0.885727  0.633540   6
# 2020-01-04 -0.553233  0.227245  0.298894 -1.769816   8
# 2020-01-05  0.682736  0.216744 -2.093730 -1.011849  10

# %%
df.iat[2,3] = 3

# %%
df2 = df.copy()

# %%
df2[df2 < 1] = 1

# %%
df2
# Out:
#               A    B    C    D   E
# 2020-01-01  1.0  1.0  1.0  1.0   2
# 2020-01-02  1.0  1.0  1.0  1.0   4
# 2020-01-03  1.0  1.0  1.0  3.0   6
# 2020-01-04  1.0  1.0  1.0  1.0   8
# 2020-01-05  1.0  1.0  1.0  1.0  10

# %%
df['A']=np.nan

# %%
df
# Out:
#              A         B         C         D   E
# 2020-01-01 NaN -1.950644  0.454098  0.585482   2
# 2020-01-02 NaN -0.538359 -0.151470  0.393029   4
# 2020-01-03 NaN  0.773024 -0.885727  3.000000   6
# 2020-01-04 NaN  0.227245  0.298894 -1.769816   8
# 2020-01-05 NaN  0.216744 -2.093730 -1.011849  10

# %%
df['A']=np.random.randn(5)

# %%
df
# Out:
#                    A         B         C         D   E
# 2020-01-01 -1.306599 -1.950644  0.454098  0.585482   2
# 2020-01-02  0.579916 -0.538359 -0.151470  0.393029   4
# 2020-01-03  1.068393  0.773024 -0.885727  3.000000   6
# 2020-01-04  0.385896  0.227245  0.298894 -1.769816   8
# 2020-01-05 -0.008350  0.216744 -2.093730 -1.011849  10

# %%
df2['A']=np.nan

# %%
df2
# Out:
#              A    B    C    D   E
# 2020-01-01 NaN  1.0  1.0  1.0   2
# 2020-01-02 NaN  1.0  1.0  1.0   4
# 2020-01-03 NaN  1.0  1.0  3.0   6
# 2020-01-04 NaN  1.0  1.0  1.0   8
# 2020-01-05 NaN  1.0  1.0  1.0  10

# %%
df2 = df.copy()

# %%
df['2020-01-01']=np.nan

# %%
df.drop(columns='2020-01-01')
# Out:
#                    A         B         C         D   E
# 2020-01-01 -1.306599 -1.950644  0.454098  0.585482   2
# 2020-01-02  0.579916 -0.538359 -0.151470  0.393029   4
# 2020-01-03  1.068393  0.773024 -0.885727  3.000000   6
# 2020-01-04  0.385896  0.227245  0.298894 -1.769816   8
# 2020-01-05 -0.008350  0.216744 -2.093730 -1.011849  10

# %%
df2.iat[0,0]=np.nan

# %%
df2
# Out:
#                    A         B         C         D   E
# 2020-01-01       NaN -1.950644  0.454098  0.585482   2
# 2020-01-02  0.579916 -0.538359 -0.151470  0.393029   4
# 2020-01-03  1.068393  0.773024 -0.885727  3.000000   6
# 2020-01-04  0.385896  0.227245  0.298894 -1.769816   8
# 2020-01-05 -0.008350  0.216744 -2.093730 -1.011849  10

# %%
df2.dropna()
# Out:
#                    A         B         C         D   E
# 2020-01-02  0.579916 -0.538359 -0.151470  0.393029   4
# 2020-01-03  1.068393  0.773024 -0.885727  3.000000   6
# 2020-01-04  0.385896  0.227245  0.298894 -1.769816   8
# 2020-01-05 -0.008350  0.216744 -2.093730 -1.011849  10

# %%
df2.iat[0,0]=np.nan

# %%
df2
# Out:
#                    A         B         C         D   E
# 2020-01-01       NaN -1.950644  0.454098  0.585482   2
# 2020-01-02  0.579916 -0.538359 -0.151470  0.393029   4
# 2020-01-03  1.068393  0.773024 -0.885727  3.000000   6
# 2020-01-04  0.385896  0.227245  0.298894 -1.769816   8
# 2020-01-05 -0.008350  0.216744 -2.093730 -1.011849  10

# %%
df.fillna(value=5)
# Out:
#                    A         B         C         D   E  2020-01-01
# 2020-01-01 -1.306599 -1.950644  0.454098  0.585482   2         5.0
# 2020-01-02  0.579916 -0.538359 -0.151470  0.393029   4         5.0
# 2020-01-03  1.068393  0.773024 -0.885727  3.000000   6         5.0
# 2020-01-04  0.385896  0.227245  0.298894 -1.769816   8         5.0
# 2020-01-05 -0.008350  0.216744 -2.093730 -1.011849  10         5.0

# %%
df = df.drop(columns='2020-01-01')

# %%
pd.isna(df)
# Out:
#                 A      B      C      D      E
# 2020-01-01  False  False  False  False  False
# 2020-01-02  False  False  False  False  False
# 2020-01-03  False  False  False  False  False
# 2020-01-04  False  False  False  False  False
# 2020-01-05  False  False  False  False  False

# %%
df.mean()
# Out:
# A    0.143851
# B   -0.254398
# C   -0.475587
# D    0.239369
# E    6.000000
# dtype: float64

# %%
df.describe()
# Out:
#               A         B         C         D          E
# count  5.000000  5.000000  5.000000  5.000000   5.000000
# mean   0.143851 -0.254398 -0.475587  0.239369   6.000000
# std    0.898678  1.056816  1.043526  1.828036   3.162278
# min   -1.306599 -1.950644 -2.093730 -1.769816   2.000000
# 25%   -0.008350 -0.538359 -0.885727 -1.011849   4.000000
# 50%    0.385896  0.216744 -0.151470  0.393029   6.000000
# 75%    0.579916  0.227245  0.298894  0.585482   8.000000
# max    1.068393  0.773024  0.454098  3.000000  10.000000

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C         D   E
# 2020-01-01 -1.306599 -1.950644  0.454098  0.585482   2
# 2020-01-02 -0.726683 -2.489004  0.302627  0.978511   6
# 2020-01-03  0.341710 -1.715980 -0.583100  3.978511  12
# 2020-01-04  0.727607 -1.488735 -0.284206  2.208695  20
# 2020-01-05  0.719257 -1.271991 -2.377936  1.196846  30

# %%
df.apply(lambda x: x * 2)
# Out:
#                    A         B         C         D   E
# 2020-01-01 -2.613198 -3.901289  0.908196  1.170964   4
# 2020-01-02  1.159833 -1.076718 -0.302941  0.786058   8
# 2020-01-03  2.136787  1.546048 -1.771455  6.000000  12
# 2020-01-04  0.771793  0.454489  0.597788 -3.539632  16
# 2020-01-05 -0.016699  0.433488 -4.187459 -2.023697  20

# %%
df = pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0  2.389119  0.334544  0.092359 -1.140709
# 1  0.553264  0.366818 -2.846019  1.232682
# 2  1.809261  0.742690  0.692045 -0.798171
# 3  1.046105  0.621456  0.444755  0.704246
# 4  1.718228 -0.140021 -0.010015 -0.324376
# 5  0.488248  0.842125 -1.226752 -1.592138
# 6  0.314704 -0.842960  0.118021  1.107542
# 7  0.393507  0.416438  1.009601  0.644239
# 8 -0.067955 -1.353029 -0.103579 -0.754237
# 9  0.183969  1.070164  0.658504 -0.860280

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pieces
# Out:
# [          0         1         2         3
#  0  2.389119  0.334544  0.092359 -1.140709
#  1  0.553264  0.366818 -2.846019  1.232682
#  2  1.809261  0.742690  0.692045 -0.798171,
#            0         1         2         3
#  3  1.046105  0.621456  0.444755  0.704246
#  4  1.718228 -0.140021 -0.010015 -0.324376
#  5  0.488248  0.842125 -1.226752 -1.592138
#  6  0.314704 -0.842960  0.118021  1.107542,
#            0         1         2         3
#  7  0.393507  0.416438  1.009601  0.644239
#  8 -0.067955 -1.353029 -0.103579 -0.754237
#  9  0.183969  1.070164  0.658504 -0.860280]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  2.389119  0.334544  0.092359 -1.140709
# 1  0.553264  0.366818 -2.846019  1.232682
# 2  1.809261  0.742690  0.692045 -0.798171
# 3  1.046105  0.621456  0.444755  0.704246
# 4  1.718228 -0.140021 -0.010015 -0.324376
# 5  0.488248  0.842125 -1.226752 -1.592138
# 6  0.314704 -0.842960  0.118021  1.107542
# 7  0.393507  0.416438  1.009601  0.644239
# 8 -0.067955 -1.353029 -0.103579 -0.754237
# 9  0.183969  1.070164  0.658504 -0.860280

# %%
left = pd.DataFrame({'key': ['fa', 'foo'], 'lval': [1, 2]})

# %%
right = pd.DataFrame({'key':['fa','foo'],'rval':[4,5]})

# %%
left
# Out:
#    key  lval
# 0   fa     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0   fa     4
# 1  foo     5

# %%
pd.merge(left,right,on='key')
# Out:
#    key  lval  rval
# 0   fa     1     4
# 1  foo     2     5

# %%
both = pd.merge(left,right,on='key')

# %%
s=df.iloc[3]

# %%
s
# Out:
# 0    1.046105
# 1    0.621456
# 2    0.444755
# 3    0.704246
# Name: 3, dtype: float64

# %%
s=both.iloc[:1]

# %%
s
# Out:
#   key  lval  rval
# 0  fa     1     4

# %%
both.append(s)
# Out:
#    key  lval  rval
# 0   fa     1     4
# 1  foo     2     5
# 0   fa     1     4

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
   ....:                          'foo', 'bar', 'foo', 'foo'],
   ....:                    'B': ['one', 'one', 'two', 'three',
   ....:                          'two', 'two', 'one', 'three'],
   ....:                    'C': np.random.randn(8),
   ....:                    'D': np.random.randn(8)})
   ....:

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.827942 -0.888692
# 1  bar    one -0.252703 -0.296931
# 2  foo    two -0.281910  0.724941
# 3  bar  three  0.304623 -0.440322
# 4  foo    two -0.430775 -0.655958
# 5  bar    two  0.262389 -1.969211
# 6  foo    one -1.474087 -0.709229
# 7  foo  three -0.966440 -2.877513

# %%
df.groupby(['A','B']).describe()
# Out:
#               C                                                              \
#           count      mean       std       min       25%       50%       75%
# A   B
# bar one     1.0 -0.252703       NaN -0.252703 -0.252703 -0.252703 -0.252703
#     three   1.0  0.304623       NaN  0.304623  0.304623  0.304623  0.304623
#     two     1.0  0.262389       NaN  0.262389  0.262389  0.262389  0.262389
# foo one     2.0 -1.151014  0.456894 -1.474087 -1.312551 -1.151014 -0.989478
#     three   1.0 -0.966440       NaN -0.966440 -0.966440 -0.966440 -0.966440
#     two     2.0 -0.356343  0.105263 -0.430775 -0.393559 -0.356343 -0.319126
#
#                         D                                                    \
#                 max count      mean       std       min       25%       50%
# A   B
# bar one   -0.252703   1.0 -0.296931       NaN -0.296931 -0.296931 -0.296931
#     three  0.304623   1.0 -0.440322       NaN -0.440322 -0.440322 -0.440322
# ...

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
   .....:                    'B': ['A', 'B', 'C'] * 4,
   .....:                    'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
   .....:                    'D': np.random.randn(12),
   .....:                    'E': np.random.randn(12)})
   .....:

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.012378  0.843195
# 1     one  B  foo  2.537651 -0.682262
# 2     two  C  foo  0.900720  0.071148
# 3   three  A  bar -0.231653 -0.350256
# 4     one  B  bar  1.831745 -0.721661
# 5     one  C  bar  0.074581  0.118929
# 6     two  A  foo -0.333233  0.064576
# 7   three  B  foo -1.115884 -0.234433
# 8     one  C  foo -0.671850  1.171203
# 9     one  A  bar  0.737227 -0.000453
# 10    two  B  bar  0.209187  0.206748
# 11  three  C  bar -1.453628 -0.667129

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.737227 -1.012378
#       B  1.831745  2.537651
#       C  0.074581 -0.671850
# three A -0.231653       NaN
#       B       NaN -1.115884
#       C -1.453628       NaN
# two   A       NaN -0.333233
#       B  0.209187       NaN
#       C       NaN  0.900720

# %%
df.plot()

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.012378  0.843195
# 1     one  B  foo  2.537651 -0.682262
# 2     two  C  foo  0.900720  0.071148
# 3   three  A  bar -0.231653 -0.350256
# 4     one  B  bar  1.831745 -0.721661
# 5     one  C  bar  0.074581  0.118929
# 6     two  A  foo -0.333233  0.064576
# 7   three  B  foo -1.115884 -0.234433
# 8     one  C  foo -0.671850  1.171203
# 9     one  A  bar  0.737227 -0.000453
# 10    two  B  bar  0.209187  0.206748
# 11  three  C  bar -1.453628 -0.667129

# %%
df.rename(columns={'A':'Number'})
# Out:
#    Number  B    C         D         E
# 0     one  A  foo -1.012378  0.843195
# 1     one  B  foo  2.537651 -0.682262
# 2     two  C  foo  0.900720  0.071148
# 3   three  A  bar -0.231653 -0.350256
# 4     one  B  bar  1.831745 -0.721661
# 5     one  C  bar  0.074581  0.118929
# 6     two  A  foo -0.333233  0.064576
# 7   three  B  foo -1.115884 -0.234433
# 8     one  C  foo -0.671850  1.171203
# 9     one  A  bar  0.737227 -0.000453
# 10    two  B  bar  0.209187  0.206748
# 11  three  C  bar -1.453628 -0.667129

# %%
df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
   .....:                    "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})

# %%
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df.dtypes
# Out:
# id            int64
# raw_grade    object
# dtype: object

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df
# Out:
#    id raw_grade grade
# 0   1         a     a
# 1   2         b     b
# 2   3         b     b
# 3   4         a     a
# 4   5         a     a
# 5   6         e     e

# %%
df.dtypes
# Out:
# id              int64
# raw_grade      object
# grade        category
# dtype: object

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): [very good, good, very bad]

# %%
df.sort_values(by='grade',ascending=False)
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
ts = pd.Series(np.random.randn(1000),
   .....:                index=pd.date_range('1/1/2000', periods=1000))

# %%
ts
# Out:
# 2000-01-01    2.036650
# 2000-01-02   -0.670756
# 2000-01-03    0.025409
# 2000-01-04    0.390304
# 2000-01-05   -0.014449
#                 ...
# 2002-09-22   -0.105987
# 2002-09-23    0.111915
# 2002-09-24   -0.315121
# 2002-09-25   -0.588836
# 2002-09-26   -0.661081
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df.loc[df['raw_grade'] == 'b']
# Out:
#    id raw_grade grade
# 1   2         b  good
# 2   3         b  good
